# %%
#数据库查询操作
import pymysql
import numpy as np
import matplotlib.pyplot as plt
connect=pymysql.Connection(
    host='localhost',
    port=3306,
    user='root',
    passwd='TianMao@19940818',
    db='websecurity'   
)
cursor=connect.cursor()
#查询
sql="select * from yahoo limit 0,100"
cursor.execute(sql)
print(cursor.rowcount)
#cursor拿到了一张大的表，按行读取,使用下边读取数据内容
result=cursor.fetchall()
for row in result:
    print(row[0],row[1])
#修改数据传入参数
# sql="update csdn set passwd='%s' where id=%d"
# data=("hahahaha",'520')
# cursor.execute(sql%data)
# connect.commit()

#定义结构数据的类型
test=np.dtype([('id',np.int),('passwd','S20'),('email','S20')])
data=np.fromiter(result,dtype=test)
print(data['id'])
print(str(data['passwd']))
print(data['email'])
# Out:
# 100
# 1 @fl!pm0de@
# 2 pass
# 3 steveol
# 4 chotzi
# 5 lb2512
# 6 scotch
# 7 passwerd
# 8 flipmode
# 9 flipmode
# 10 alden2
# 11 salmon
# 12 tagoogle
# 13 giants
# 14 chapman
# 15 odom115
# 16 pass
# 17 pass
# 18 cryptic
# 19 chaos128
# 20 daisydog
# 21 m8S3ZeN4
# 22 sunshine
# 23 pramati
# 24 nissy
# 25 deuce
# 26 sandalwood
# 27 frazzle
# 28 manuel
# 29 surf5375
# 30 murgatroyd
# 31 Boblin-half
# 32 cassie
# 33 amethyst
# 34 slinker
# 35 never
# 36 jpg1224
# 37 pepper
# 38 sungjin
# 39 7heaven
# 40 associated1017
# 41 Godslove
# 42 coffee
# 43 mellobel
# 44 russell1
# 45 russell1
# 46 dmd1980
# 47 glory2be
# 48 jessie
# 49 canpost
# 50 allyson
# 51 jon1216
# 52 notllt
# 53 neenee
# 54 jmtjkbas
# 55 mygirls
# 56 croton66
# 57 peony
# 58 poet
# 59 mjp47766
# 60 starcity
# 61 laser
# 62 vmj1978
# 63 education
# 64 calypso
# 65 binxter
# 66 blackhawk
# 67 secade
# 68 lila
# 69 daniel88
# 70 lydia1
# 71 bozzie
# 72 trump49
# 73 now
# 74 stunner
# 75 temporal
# 76 elbereth
# 77 jerkoff
# ...

# %%
#测试正则表达式
import re
pattern=re.compile('A')
match=pattern.match('ABC')
print(match)
# Out:
# <_sre.SRE_Match object; span=(0, 1), match='A'>
